# %% [markdown]
# ## Question 5: Critically Evaluate Problem 4

# %% [markdown]
# #### Critically evaluate your work in part 4. Do your sequences have the properties of the training data, and if not, why not? Are your estimates credible and reliable, or is there substantial uncertainty in your results?

# %% [markdown]
# For part 4, we created a sample of 300 beats to create a synthetic RR sequence for each record. When looking at the differences between the synthetic RR sequences from bootstrapping with that sample of 300 and the real RR sequences, we can see that there are substantial differences between the two. This suggests that bootstrapping did not capture the underlying issues in temporal dependencies and rhythm patterns in a typical heartbeat.
#
# In the synthetic graph, there is much more overlap between the two records, and each RR sequence is a lot more irregular in comparison to the real data. The synthetic RR has less separation in between the two records. In the real RR sequence, the pattern is more steady, indicating that there is a more consistent heart rhythm. This suggests that there is higher variability and bootstrapping may have incurred noise that failed to preserve the physiological nature of a heartbeat.
#
# Based on the evaluation of these two graphs, there would definitely be uncertainty in our results because the graphs fail to represent the dynamics and rhythm consitency in a heartbeat sequence. The increased irregularity and overlap between the two records introduces this uncertainty and any model training based on these sequences would likely be less representative and robust.
